# %%
'''
Created on Oct 19, 2010

@author: Peter
'''
from numpy import *

def loadDataSet():
    postingList=[['my', 'dog', 'has', 'flea', 'problems', 'help', 'please'],
                 ['maybe', 'not', 'take', 'him', 'to', 'dog', 'park', 'stupid'],
                 ['my', 'dalmation', 'is', 'so', 'cute', 'I', 'love', 'him'],
                 ['stop', 'posting', 'stupid', 'worthless', 'garbage'],
                 ['mr', 'licks', 'ate', 'my', 'steak', 'how', 'to', 'stop', 'him'],
                 ['quit', 'buying', 'worthless', 'dog', 'food', 'stupid']]
    classVec = [0,1,0,1,0,1]    #1 is abusive, 0 not
    return postingList,classVec
                 
def createVocabList(dataSet):
    vocabSet = set([])  #create empty set
    for document in dataSet:
        vocabSet = vocabSet | set(document) #union of the two sets
    return list(vocabSet)

def setOfWords2Vec(vocabList, inputSet):
    returnVec = [0]*len(vocabList)
    for word in inputSet:	
        if word in vocabList:
            returnVec[vocabList.index(word)] = 1
        else: print "the word: %s is not in my Vocabulary!" % word
    return returnVec

def trainNB0(trainMatrix,trainCategory):
    numTrainDocs = len(trainMatrix)
    numWords = len(trainMatrix[0])
    pAbusive = sum(trainCategory)/float(numTrainDocs)
    p0Num = ones(numWords); p1Num = ones(numWords)      #change to ones() 
    p0Denom = 2.0; p1Denom = 2.0                        #change to 2.0
    for i in range(numTrainDocs):
        if trainCategory[i] == 1:
            p1Num += trainMatrix[i]
            p1Denom += sum(trainMatrix[i])
        else:
            p0Num += trainMatrix[i]
            p0Denom += sum(trainMatrix[i])
    p1Vect = log(p1Num/p1Denom)          #change to log()
    p0Vect = log(p0Num/p0Denom)          #change to log()
    return p0Vect,p1Vect,pAbusive

def classifyNB(vec2Classify, p0Vec, p1Vec, pClass1):
    p1 = sum(vec2Classify * p1Vec) + log(pClass1)    #element-wise mult
    p0 = sum(vec2Classify * p0Vec) + log(1.0 - pClass1)
    if p1 > p0:
        return 1
    else: 
        return 0
    
def bagOfWords2VecMN(vocabList, inputSet):
    returnVec = [0]*len(vocabList)
    for word in inputSet:
        if word in vocabList:
            returnVec[vocabList.index(word)] += 1
    return returnVec

def testingNB():
    listOPosts,listClasses = loadDataSet()
    myVocabList = createVocabList(listOPosts)
    trainMat=[]
    for postinDoc in listOPosts:
        trainMat.append(setOfWords2Vec(myVocabList, postinDoc))
    p0V,p1V,pAb = trainNB0(array(trainMat),array(listClasses))
    testEntry = ['love', 'my', 'dalmation']
    thisDoc = array(setOfWords2Vec(myVocabList, testEntry))
    print testEntry,'classified as: ',classifyNB(thisDoc,p0V,p1V,pAb)
    testEntry = ['stupid', 'garbage']
    thisDoc = array(setOfWords2Vec(myVocabList, testEntry))
    print testEntry,'classified as: ',classifyNB(thisDoc,p0V,p1V,pAb)

def textParse(bigString):    #input is big string, #output is word list
    import re
    listOfTokens = re.split(r'\W*', bigString)
    return [tok.lower() for tok in listOfTokens if len(tok) > 2] 
    
def spamTest():
    docList=[]; classList = []; fullText =[]
    for i in range(1,26):
        wordList = textParse(open('email/spam/%d.txt' % i).read())
        docList.append(wordList)
        fullText.extend(wordList)
        classList.append(1)
        wordList = textParse(open('email/ham/%d.txt' % i).read())
        docList.append(wordList)
        fullText.extend(wordList)
        classList.append(0)
    vocabList = createVocabList(docList)#create vocabulary
    trainingSet = range(50); testSet=[]           #create test set
    for i in range(10):
        randIndex = int(random.uniform(0,len(trainingSet)))
        testSet.append(trainingSet[randIndex])
        del(trainingSet[randIndex])  
    trainMat=[]; trainClasses = []
    for docIndex in trainingSet:#train the classifier (get probs) trainNB0
        trainMat.append(bagOfWords2VecMN(vocabList, docList[docIndex]))
        trainClasses.append(classList[docIndex])
    p0V,p1V,pSpam = trainNB0(array(trainMat),array(trainClasses))
    errorCount = 0
    for docIndex in testSet:        #classify the remaining items
        wordVector = bagOfWords2VecMN(vocabList, docList[docIndex])
        if classifyNB(array(wordVector),p0V,p1V,pSpam) != classList[docIndex]:
            errorCount += 1
            print "classification error",docList[docIndex]
    print 'the error rate is: ',float(errorCount)/len(testSet)
    #return vocabList,fullText

def calcMostFreq(vocabList,fullText):
    import operator
    freqDict = {}
    for token in vocabList:
        freqDict[token]=fullText.count(token)
    sortedFreq = sorted(freqDict.iteritems(), key=operator.itemgetter(1), reverse=True) 
    return sortedFreq[:30]       

def localWords(feed1,feed0):
    import feedparser
    docList=[]; classList = []; fullText =[]
    minLen = min(len(feed1['entries']),len(feed0['entries']))
    for i in range(minLen):
        wordList = textParse(feed1['entries'][i]['summary'])
        docList.append(wordList)
        fullText.extend(wordList)
        classList.append(1) #NY is class 1
        wordList = textParse(feed0['entries'][i]['summary'])
        docList.append(wordList)
        fullText.extend(wordList)
        classList.append(0)
    vocabList = createVocabList(docList)#create vocabulary
    top30Words = calcMostFreq(vocabList,fullText)   #remove top 30 words
    for pairW in top30Words:
        if pairW[0] in vocabList: vocabList.remove(pairW[0])
    trainingSet = range(2*minLen); testSet=[]           #create test set
    for i in range(20):
        randIndex = int(random.uniform(0,len(trainingSet)))
        testSet.append(trainingSet[randIndex])
        del(trainingSet[randIndex])  
    trainMat=[]; trainClasses = []
    for docIndex in trainingSet:#train the classifier (get probs) trainNB0
        trainMat.append(bagOfWords2VecMN(vocabList, docList[docIndex]))
        trainClasses.append(classList[docIndex])
    p0V,p1V,pSpam = trainNB0(array(trainMat),array(trainClasses))
    errorCount = 0
    for docIndex in testSet:        #classify the remaining items
        wordVector = bagOfWords2VecMN(vocabList, docList[docIndex])
        if classifyNB(array(wordVector),p0V,p1V,pSpam) != classList[docIndex]:
            errorCount += 1
    print 'the error rate is: ',float(errorCount)/len(testSet)
    return vocabList,p0V,p1V

def getTopWords(ny,sf):
    import operator
    vocabList,p0V,p1V=localWords(ny,sf)
    topNY=[]; topSF=[]
    for i in range(len(p0V)):
        if p0V[i] > -6.0 : topSF.append((vocabList[i],p0V[i]))
        if p1V[i] > -6.0 : topNY.append((vocabList[i],p1V[i]))
    sortedSF = sorted(topSF, key=lambda pair: pair[1], reverse=True)
    print "SF**SF**SF**SF**SF**SF**SF**SF**SF**SF**SF**SF**SF**SF**SF**SF**"
    for item in sortedSF:
        print item[0]
    sortedNY = sorted(topNY, key=lambda pair: pair[1], reverse=True)
    print "NY**NY**NY**NY**NY**NY**NY**NY**NY**NY**NY**NY**NY**NY**NY**NY**"
    for item in sortedNY:
        print item[0]

# %%
listOPosts, listClasses = loadDataSet()
myVocabList = createVocabList(listOPosts)
trainMat = []
for postinDoc in listOPosts:
    trainMat.append(setOfWords2Vec(myVocabList, postinDoc))
p0V, p1V, pAb = trainNB0(trainMat, listClasses)

# %%
testingNB()
# Out:
# ['love', 'my', 'dalmation'] classified as:  0
# ['stupid', 'garbage'] classified as:  1

# %%
spamTest()
# Out:
# the error rate is:  0.0

# %%
spamTest()
# Out:
# classification error ['home', 'based', 'business', 'opportunity', 'knocking', 'your', 'door', 'don', 'rude', 'and', 'let', 'this', 'chance', 'you', 'can', 'earn', 'great', 'income', 'and', 'find', 'your', 'financial', 'life', 'transformed', 'learn', 'more', 'here', 'your', 'success', 'work', 'from', 'home', 'finder', 'experts']
# the error rate is:  0.1

# %%
import feedparser
ny = feedparser.parse('http://newyork.craigslist.org/stp/index.rss')
ny['entries']
# Out:
# [{'dc_source': u'http://newyork.craigslist.org/brk/stp/6297487660.html',
#   'dc_type': u'text',
#   'id': u'http://newyork.craigslist.org/brk/stp/6297487660.html',
#   'language': u'en-us',
#   'link': u'http://newyork.craigslist.org/brk/stp/6297487660.html',
#   'links': [{'href': u'http://newyork.craigslist.org/brk/stp/6297487660.html',
#     'rel': u'alternate',
#     'type': u'text/html'}],
#   'published': u'2017-09-16T22:02:10-04:00',
#   'published_parsed': time.struct_time(tm_year=2017, tm_mon=9, tm_mday=17, tm_hour=2, tm_min=2, tm_sec=10, tm_wday=6, tm_yday=260, tm_isdst=0),
#   'rights': u'copyright 2017 craiglist',
#   'rights_detail': {'base': u'https://newyork.craigslist.org/search/stp?format=rss',
#    'language': None,
#    'type': u'text/plain',
#    'value': u'copyright 2017 craiglist'},
#   'summary': u"I'm bored text me and let's see where this can go 9one7 2one4 ten14. I am open to all race's please be female.",
#   'summary_detail': {'base': u'https://newyork.craigslist.org/search/stp?format=rss',
#    'language': None,
#    'type': u'text/html',
#    'value': u"I'm bored text me and let's see where this can go 9one7 2one4 ten14. I am open to all race's please be female."},
#   'title': u'Text buddy - m4w (Bedstuy)',
#   'title_detail': {'base': u'https://newyork.craigslist.org/search/stp?format=rss',
#    'language': None,
#    'type': u'text/plain',
#    'value': u'Text buddy - m4w (Bedstuy)'},
#   'updated': u'2017-09-16T22:02:10-04:00',
#   'updated_parsed': time.struct_time(tm_year=2017, tm_mon=9, tm_mday=17, tm_hour=2, tm_min=2, tm_sec=10, tm_wday=6, tm_yday=260, tm_isdst=0)},
#  {'dc_source': u'http://newyork.craigslist.org/brk/stp/6298796387.html',
#   'dc_type': u'text',
#   'id': u'http://newyork.craigslist.org/brk/stp/6298796387.html',
#   'language': u'en-us',
#   'link': u'http://newyork.craigslist.org/brk/stp/6298796387.html',
#   'links': [{'href': u'http://newyork.craigslist.org/brk/stp/6298796387.html',
#     'rel': u'alternate',
#     'type': u'text/html'}],
#   'published': u'2017-09-16T21:59:45-04:00',
#   'published_parsed': time.struct_time(tm_year=2017, tm_mon=9, tm_mday=17, tm_hour=1, tm_min=59, tm_sec=45, tm_wday=6, tm_yday=260, tm_isdst=0),
#   'rights': u'copyright 2017 craiglist',
#   'rights_detail': {'base': u'https://newyork.craigslist.org/search/stp?format=rss',
#    'language': None,
#    'type': u'text/plain',
#    'value': u'copyright 2017 craiglist'},
#   'summary': u'Hi there. Any ladies out here up for chatting? Nothing obnoxious or crazy just chatting. Im 42 Black slim live in Bedstuy relaxed but bored out of my mind. Please no scammers or website promoters. Thanks and stay cool!',
#   'summary_detail': {'base': u'https://newyork.craigslist.org/search/stp?format=rss',
#    'language': None,
#    'type': u'text/html',
#    'value': u'Hi there. Any ladies out here up for chatting? Nothing obnoxious or crazy just chatting. Im 42 Black slim live in Bedstuy relaxed but bored out of my mind. Please no scammers or website promoters. Thanks and stay cool!'},
#   'title': u'Skype - m4w (Bedstuy)',
#   'title_detail': {'base': u'https://newyork.craigslist.org/search/stp?format=rss',
#    'language': None,
#    'type': u'text/plain',
#    'value': u'Skype - m4w (Bedstuy)'},
#   'updated': u'2017-09-16T21:59:45-04:00',
#   'updated_parsed': time.struct_time(tm_year=2017, tm_mon=9, tm_mday=17, tm_hour=1, tm_min=59, tm_sec=45, tm_wday=6, tm_yday=260, tm_isdst=0)},
#  {'dc_source': u'http://newyork.craigslist.org/brx/stp/6305324902.html',
#   'dc_type': u'text',
#   'enc_enclosure': {'resource': u'https://images.craigslist.org/00707_4uwfhHRAI9w_300x300.jpg',
#    'type': u'image/jpeg'},
#   'id': u'http://newyork.craigslist.org/brx/stp/6305324902.html',
#   'language': u'en-us',
#   'link': u'http://newyork.craigslist.org/brx/stp/6305324902.html',
#   'links': [{'href': u'http://newyork.craigslist.org/brx/stp/6305324902.html',
#     'rel': u'alternate',
#     'type': u'text/html'}],
#   'published': u'2017-09-16T21:57:45-04:00',
#   'published_parsed': time.struct_time(tm_year=2017, tm_mon=9, tm_mday=17, tm_hour=1, tm_min=57, tm_sec=45, tm_wday=6, tm_yday=260, tm_isdst=0),
#   'rights': u'copyright 2017 craiglist',
#   'rights_detail': {'base': u'https://newyork.craigslist.org/search/stp?format=rss',
#    'language': None,
#    'type': u'text/plain',
#    'value': u'copyright 2017 craiglist'},
#   'summary': u'Hello. Cute, handsome nice guy here looking to meet nice gal out there, not looking to jump into a relationship at the moment. I want to connect and meet with new people out there, build a friendship to start and see where it goes from there. I am Hi ...',
#   'summary_detail': {'base': u'https://newyork.craigslist.org/search/stp?format=rss',
#    'language': None,
#    'type': u'text/html',
#    'value': u'Hello. Cute, handsome nice guy here looking to meet nice gal out there, not looking to jump into a relationship at the moment. I want to connect and meet with new people out there, build a friendship to start and see where it goes from there. I am Hi ...'},
#   'title': u'Handsome guy for pretty gal out there - m4w (Southern Blvd. & Westchester Ave.)',
#   'title_detail': {'base': u'https://newyork.craigslist.org/search/stp?format=rss',
#    'language': None,
#    'type': u'text/plain',
#    'value': u'Handsome guy for pretty gal out there - m4w (Southern Blvd. & Westchester Ave.)'},
#   'updated': u'2017-09-16T21:57:45-04:00',
#   'updated_parsed': time.struct_time(tm_year=2017, tm_mon=9, tm_mday=17, tm_hour=1, tm_min=57, tm_sec=45, tm_wday=6, tm_yday=260, tm_isdst=0)},
#  {'dc_source': u'http://newyork.craigslist.org/brx/stp/6305325181.html',
#   'dc_type': u'text',
#   'enc_enclosure': {'resource': u'https://images.craigslist.org/00M0M_cgX6lBHYOVK_300x300.jpg',
#    'type': u'image/jpeg'},
#   'id': u'http://newyork.craigslist.org/brx/stp/6305325181.html',
#   'language': u'en-us',
#   'link': u'http://newyork.craigslist.org/brx/stp/6305325181.html',
#   'links': [{'href': u'http://newyork.craigslist.org/brx/stp/6305325181.html',
#     'rel': u'alternate',
#     'type': u'text/html'}],
#   'published': u'2017-09-16T21:57:01-04:00',
#   'published_parsed': time.struct_time(tm_year=2017, tm_mon=9, tm_mday=17, tm_hour=1, tm_min=57, tm_sec=1, tm_wday=6, tm_yday=260, tm_isdst=0),
#   'rights': u'copyright 2017 craiglist',
#   'rights_detail': {'base': u'https://newyork.craigslist.org/search/stp?format=rss',
#    'language': None,
#    'type': u'text/plain',
#    'value': u'copyright 2017 craiglist'},
#   'summary': u'Hello everyone. 38 year old hispanic male here, seeking a nice friendship to do casual things here and there like...Shopping, Movies, Lunch or Dinner, Museums, theme parks, things of that nature. I am currently single, stable and employed full time,  ...',
#   'summary_detail': {'base': u'https://newyork.craigslist.org/search/stp?format=rss',
#    'language': None,
#    'type': u'text/html',
#    'value': u'Hello everyone. 38 year old hispanic male here, seeking a nice friendship to do casual things here and there like...Shopping, Movies, Lunch or Dinner, Museums, theme parks, things of that nature. I am currently single, stable and employed full time,  ...'},
#   'title': u'I want to be your friend. :-) - m4w (Southern Blvd & Westchester ave.)',
#   'title_detail': {'base': u'https://newyork.craigslist.org/search/stp?format=rss',
#    'language': None,
#    'type': u'text/plain',
#    'value': u'I want to be your friend. :-) - m4w (Southern Blvd & Westchester ave.)'},
#   'updated': u'2017-09-16T21:57:01-04:00',
#   'updated_parsed': time.struct_time(tm_year=2017, tm_mon=9, tm_mday=17, tm_hour=1, tm_min=57, tm_sec=1, tm_wday=6, tm_yday=260, tm_isdst=0)},
#  {'dc_source': u'http://newyork.craigslist.org/mnh/stp/6287242175.html',
#   'dc_type': u'text',
#   'id': u'http://newyork.craigslist.org/mnh/stp/6287242175.html',
#   'language': u'en-us',
#   'link': u'http://newyork.craigslist.org/mnh/stp/6287242175.html',
#   'links': [{'href': u'http://newyork.craigslist.org/mnh/stp/6287242175.html',
#     'rel': u'alternate',
#     'type': u'text/html'}],
#   'published': u'2017-09-16T21:52:42-04:00',
#   'published_parsed': time.struct_time(tm_year=2017, tm_mon=9, tm_mday=17, tm_hour=1, tm_min=52, tm_sec=42, tm_wday=6, tm_yday=260, tm_isdst=0),
#   'rights': u'copyright 2017 craiglist',
#   'rights_detail': {'base': u'https://newyork.craigslist.org/search/stp?format=rss',
#    'language': None,
#    'type': u'text/plain',
#    'value': u'copyright 2017 craiglist'},
#   'summary': u"white male 40's no kids seeking nice chubby or slim asian caucasian latina female friend with cute feet from age late 20's to late 40's to go out from time to time to movies dinners lunch be my treat plus income pic 4 pic.",
#   'summary_detail': {'base': u'https://newyork.craigslist.org/search/stp?format=rss',
#    'language': None,
#    'type': u'text/html',
#    'value': u"white male 40's no kids seeking nice chubby or slim asian caucasian latina female friend with cute feet from age late 20's to late 40's to go out from time to time to movies dinners lunch be my treat plus income pic 4 pic."},
#   'title': u'cute feet - m4w (manhattan)',
#   'title_detail': {'base': u'https://newyork.craigslist.org/search/stp?format=rss',
#    'language': None,
#    'type': u'text/plain',
#    'value': u'cute feet - m4w (manhattan)'},
#   'updated': u'2017-09-16T21:52:42-04:00',
#   'updated_parsed': time.struct_time(tm_year=2017, tm_mon=9, tm_mday=17, tm_hour=1, tm_min=52, tm_sec=42, tm_wday=6, tm_yday=260, tm_isdst=0)},
#  {'dc_source': u'http://newyork.craigslist.org/que/stp/6309144694.html',
#   'dc_type': u'text',
#   'id': u'http://newyork.craigslist.org/que/stp/6309144694.html',
#   'language': u'en-us',
#   'link': u'http://newyork.craigslist.org/que/stp/6309144694.html',
#   'links': [{'href': u'http://newyork.craigslist.org/que/stp/6309144694.html',
#     'rel': u'alternate',
#     'type': u'text/html'}],
#   'published': u'2017-09-16T21:52:13-04:00',
#   'published_parsed': time.struct_time(tm_year=2017, tm_mon=9, tm_mday=17, tm_hour=1, tm_min
#   'summary_detail': {'base': u'https://newyork.craigslist.org/search/stp?format=rss',
#    'language': None,
#    'type': u'text/html',
#    'value': u"Because to be beautiful is to KNOW that you are... \nAnd to love everything and everyone that surrounds us unconditionally... \nIs to genuinely understand that maybe everything we were granted the ability to see... \nWasn't designed to be seen as perfec ..."},
#   'title': u'Because to be beautiful is to KNOW that you are... - m4w',
#   'title_detail': {'base': u'https://newyork.craigslist.org/search/stp?format=rss',
#    'language': None,
#    'type': u'text/plain',
#    'value': u'Because to be beautiful is to KNOW that you are... - m4w'},
#   'updated': u'2017-09-16T21:46:26-04:00',
#   'updated_parsed': time.struct_time(tm_year=2017, tm_mon=9, tm_mday=17, tm_hour=1, tm_min=46, tm_sec=26, tm_wday=6, tm_yday=260, tm_isdst=0)},
#  {'dc_source': u'http://newyork.craigslist.org/mnh/stp/6284454665.html',
#   'dc_type': u'text',
#   'enc_enclosure': {'resource': u'https://images.craigslist.org/00E0E_cLhDmFZbelH_300x300.jpg',
#    'type': u'image/jpeg'},
#   'id': u'http://newyork.craigslist.org/mnh/stp/6284454665.html',
#   'language': u'en-us',
#   'link': u'http://newyork.craigslist.org/mnh/stp/6284454665.html',
#   'links': [{'href': u'http://newyork.craigslist.org/mnh/stp/6284454665.html',
#     'rel': u'alternate',
#     'type': u'text/html'}],
#   'published': u'2017-09-16T21:45:54-04:00',
#   'published_parsed': time.struct_time(tm_year=2017, tm_mon=9, tm_mday=17, tm_hour=1, tm_min=45, tm_sec=54, tm_wday=6, tm_yday=260, tm_isdst=0),
#   'rights': u'copyright 2017 craiglist',
#   'rights_detail': {'base': u'https://newyork.craigslist.org/search/stp?format=rss',
#    'language': None,
#    'type': u'text/plain',
#    'value': u'copyright 2017 craiglist'},
#   'summary': u"When's the last time you've noticed the sun, moon & the stars?...Tell me when's the last time you've noticed something was missing in your life...&#8232;And you tried locating it inside of your heart...When was the last time you felt gratitude for th ...",
#   'summary_detail': {'base': u'https://newyork.craigslist.org/search/stp?format=rss',
#    'language': None,
#    'type': u'text/html',
#    'value': u"When's the last time you've noticed the sun, moon & the stars?...Tell me when's the last time you've noticed something was missing in your life...&#8232;And you tried locating it inside of your heart...When was the last time you felt gratitude for th ..."},
#   'title': u"When's The Last Time You've Noticed The Sun, Moon & The Stars?... - m4w",
#   'title_detail': {'base': u'https://newyork.craigslist.org/search/stp?format=rss',
#    'language': None,
#    'type': u'text/plain',
#    'value': u"When's The Last Time You've Noticed The Sun, Moon & The Stars?... - m4w"},
#   'updated': u'2017-09-16T21:45:54-04:00',
#   'updated_parsed': time.struct_time(tm_year=2017, tm_mon=9, tm_mday=17, tm_hour=1, tm_min=45, tm_sec=54, tm_wday=6, tm_yday=260, tm_isdst=0)},
#  {'dc_source': u'http://newyork.craigslist.org/mnh/stp/6284460155.html',
#   'dc_type': u'text',
#   'enc_enclosure': {'resource': u'https://images.craigslist.org/00i0i_doycCIBXsdd_300x300.jpg',
#    'type': u'image/jpeg'},
#   'id': u'http://newyork.craigslist.org/mnh/stp/6284460155.html',
#   'language': u'en-us',
#   'link': u'http://newyork.craigslist.org/mnh/stp/6284460155.html',
#   'links': [{'href': u'http://newyork.craigslist.org/mnh/stp/6284460155.html',
#     'rel': u'alternate',
#     'type': u'text/html'}],
#   'published': u'2017-09-16T21:45:53-04:00',
#   'published_parsed': time.struct_time(tm_year=2017, tm_mon=9, tm_mday=17, tm_hour=1, tm_min=45, tm_sec=53, tm_wday=6, tm_yday=260, tm_isdst=0),
#   'rights': u'copyright 2017 craiglist',
#   'rights_detail': {'base': u'https://newyork.craigslist.org/search/stp?format=rss',
#    'language': None,
#    'type': u'text/plain',
#    'value': u'copyright 2017 craiglist'},
#   'summary': u"And then a broken promise leads...To a broken heart that bleeds...But you still look at the sun...Even though it's hard to see...You just close your eyes and dream...Even though it's hard to breathe...Because the truest part of you...&#8232;Still giv ...",
#   'summary_detail': {'base': u'https://newyork.craigslist.org/search/stp?format=rss',
#    'language': None,
#    'type': u'text/html',
#    'value': u"And then a broken promise leads...To a broken heart that bleeds...But you still look at the sun...Even though it's hard to see...You just close your eyes and dream...Even though it's hard to breathe...Because the truest part of you...&#8232;Still giv ..."},
#   'title': u'And Then A Broken Promise Leads... - m4w',
#   'title_detail': {'base': u'https://newyork.craigslist.org/search/stp?format=rss',
#    'language': None,
#    'type': u'text/plain',
#    'value': u'And Then A Broken Promise Leads... - m4w'},
#   'updated': u'2017-09-16T21:45:53-04:00',
#   'updated_parsed': time.struct_time(tm_year=2017, tm_mon=9, tm_mday=17, tm_hour=1, tm_min=45, tm_sec=53, tm_wday=6, tm_yday=260, tm_isdst=0)},
#  {'dc_source': u'http://newyork.craigslist.org/mnh/stp/6309145581.html',
#   'dc_type': u'text',
#   'id': u'http://newyork.craigslist.org/mnh/stp/6309145581.html',
#   'language': u'en-us',
#   'link': u'http://newyork.craigslist.org/mnh/stp/6309145581.html',
#   'links': [{'href': u'http://newyork.craigslist.org/mnh/stp/6309145581.html',
#     'rel': u'alternate',
#     'type': u'text/html'}],
#   'published': u'2017-09-16T21:43:19-04:00',
#   'published_parsed': time.struct_time(tm_year=2017, tm_mon=9, tm_mday=17, tm_hour=1, tm_min=43, tm_sec=19, tm_wday=6, tm_yday=260, tm_isdst=0),
#   'rights': u'copyright 2017 craiglist',
#   'rights_detail': {'base': u'https://newyork.craigslist.org/search/stp?format=rss',
#    'language': None,
#    'type': u'text/plain',
#    'value': u'copyright 2017 craiglist'},
#   'summary': u"Any nice asian women want to fool around tonight? BBW preferred but not a must. We could makeout or I could give you a foot massage. To be honest, my ex-gf is an asian bbw and I'm missing her, hence my ad. So even if you don't want to mess around, we ...",
#   'summary_detail': {'base': u'https://newyork.craigslist.org/search/stp?format=rss',
#    'language': None,
#    'type': u'text/html',
#    'value': u"Any nice asian women want to fool around tonight? BBW preferred but not a must. We could makeout or I could give you a foot massage. To be honest, my ex-gf is an asian bbw and I'm missing her, hence my ad. So even if you don't want to mess around, we ..."},
#   'title': u'Seeking a nice asian bbw - m4w (East Village)',
#   'title_detail': {'base': u'https://newyork.craigslist.org/search/stp?format=rss',
#    'language': None,
#    'type': u'text/plain',
#    'value': u'Seeking a nice asian bbw - m4w (East Village)'},
#   'updated': u'2017-09-16T21:43:19-04:00',
#   'updated_parsed': time.struct_time(tm_year=2017, tm_mon=9, tm_mday=17, tm_hour=1, tm_min=43, tm_sec=19, tm_wday=6, tm_yday=260, tm_isdst=0)},
#  {'dc_source': u'http://newyork.craigslist.org/mnh/stp/6309151623.html',
#   'dc_type': u'text',
#   'id': u'http://newyork.craigslist.org/mnh/stp/6309151623.html',
#   'language': u'en-us',
#   'link': u'http://newyork.craigslist.org/mnh/stp/6309151623.html',
#   'links': [{'href': u'http://newyork.craigslist.org/mnh/stp/6309151623.html',
#     'rel': u'alternate',
#     'type': u'text/html'}],
#   'published': u'2017-09-16T21:37:10-04:00',
#   'published_parsed': time.struct_time(tm_year=2017, tm_mon=9, tm_mday=17, tm_hour=1, tm_min=37, tm_sec=10, tm_wday=6, tm_yday=260, tm_isdst=0),
#   'rights': u'copyright 2017 craiglist',
#   'rights_detail': {'base': u'https://newyork.craigslist.org/search/stp?format=rss',
#    'language': None,
#    'type': u'text/plain',
#    'value': u'copyright 2017 craiglist'},
#   'summary': u'I am a generous, educated, personable man seeking an open minded woman \nto develop an ongoing relationship involving fantasy role-play. Lets develop a mutually satisfying, discreet and \nsatisfying relationship. You may be either dominant or submissiv ...',
#   'summary_detail': {'base': u'https://newyork.craigslist.org/search/stp?format=rss',
#    'language': None,
#    'type': u'text/html',
#    'value': u'I am a generous, educated, personable man seeking an open minded woman \nto develop an ongoing relationship involving fantasy role-play. Lets develop a mutually satisfying, discreet and \nsatisfying relationship. You may be either dominant or submissiv ...'},
#   'title': u'Female Role-Play Partner Wanted - m4w (Upper East Side)',
#   'title_detail': {'base': u'https://newyork.craigslist.org/search/stp?format=rss',
#    'language': None,
#    'type': u'text/plain',
#    'value': u'Female Role-Play Partner Wanted - m4w (Upper East Side)'},
#   'updated': u'2017-09-16T21:37:10-04:00',
#   'updated_parsed': time.struct_time(tm_year=2017, tm_mon=9, tm_mday=17, tm_hour=1, tm_min=37, tm_sec=10, tm_wday=6, tm_yday=260, tm_isdst=0)},
#  {'dc_source': u'http://newyork.craigslist.org/brk/stp/6309144344.html',
#   'dc_type': u'text',
#   'enc_enclosure': {'resource': u'https://images.craigslist.org/00G0G_gS99ewDeuo2_300x300.jpg',
#    'type': u'image/jpeg'},
#   'id': u'http://newyork.craigslist.org/brk/stp/6309144344.html',
#   'language': u'en-us',
#   'link': u'http://newyork.craigslist.org/brk/stp/6309144344.html',
#   'links': [{'href': u'http://newyork.craigslist.org/brk/stp/6309144344.html',
#     'rel': u'alternate',
#     'type': u'text/html'}],
#   'published': u'2017-09-16T21:27:50-04:00',
#   'published_parsed': time.struct_time(tm_year=2017, tm_mon=9, tm_mday=17, tm_hour=1, tm_min=27, tm_sec=50, tm_wday=6, tm_yday=260, tm_isdst=0),
#   'rights': u'copyright 2017 craiglist',
#   'rights_detail': {'base': u'https://newyork.craigslist.org/search/stp?format=rss',
#    'language': None,
#    'type': u'text/plain',
#    'value': u'copyright 2017 craiglist'},
#   'summary': u"**Please if you're willing to reply also be willing to meetup &amp; do something soon afterwards** \nSo the title says it all. \nI'm an introvert that wants to get out of my shell. \nI wanna do more &amp; create lasting memories. \nI'm looking for a fema ...",
#   'summary_detail': {'base': u'https://newyork.craigslist.org/search/stp?format=rss',
#    'language': None,
#    'type': u'text/html',
#    'value': u"**Please if you're willing to reply also be willing to meetup &amp; do something soon afterwards** \nSo the title says it all. \nI'm an introvert that wants to get out of my shell. \nI wanna do more &amp; create lasting memories. \nI'm looking for a fema ..."},
#   'title': u'Introvert wanting friends - w4w (Anywhere)',
#   'title_detail': {'base': u'https://newyork.craigslist.org/search/stp?format=rss',
#    'language': None,
#    'type': u'text/plain',
#    'value': u'Introvert wanting friends - w4w (Anywhere)'},
#   'updated': u'2017-09-16T21:27:50-04:00',
#   'updated_parsed': time.struct_time(tm_year=2017, tm_mon=9, tm_mday=17, tm_hour=1, tm_min=27, tm_sec=50, tm_wday=6, tm_yday=260, tm_isdst=0)},
#  {'dc_source': u'http://newyork.craigslist.org/brx/stp/6309131104.html',
#   'dc_type': u'text',
#   'id': u'http://newyork.craigslist.org/brx/stp/6309131104.html',
#   'language': u'en-us',
#   'link': u'http://newyork.craigslist.org/brx/stp/6309131104.html',
#   'links': [{'href': u'http://newyork.craigslist.org/brx/stp/6309131104.html',
#     'rel': u'alternate',
#     'type': u'text/html'}],
#   'published': u'2017-09-16T21:25:27-04:00',
#   'published_parsed': time.struct_time(tm_year=2017, tm_mon=9, tm_mday=17, tm_hour=1, tm_min=25, tm_sec=27, tm_wday=6, tm_yday=260, tm_isdst=0),
#   'rights': u'copyright 2017 craiglist',
#   'rights_detail': {'base': u'https://newyork.craigslist.org/search/stp?format=rss',
#    'language': None,
#    'type': u'text/plain',
#    'value': u'copyright 2017 craiglist'},
#   'summary': u"Hello I'm Cyn \nI'm looking for a few best friends that's female strippers !! I want to build a friendship or maybe something more ,someone I can chill with, talk to, go out together, travel, shopping etc.... The reason I'm interested in having a fema ...",
#   'summary_detail': {'base': u'https://newyork.craigslist.org/search/stp?format=rss',
#    'language': None,
#    'type': u'text/html',
#    'value': u"Hello I'm Cyn \nI'm looking for a few best friends that's female strippers !! I want to build a friendship or maybe something more ,someone I can chill with, talk to, go out together, travel, shopping etc.... The reason I'm interested in having a fema ..."},
#   'title': u'Looking for FEMALE STRIPPERS ASAP (New York)',
#   'title_detail': {'base': u'https://newyork.craigslist.org/search/stp?format=rss',
#    'language': None,
#    'type': u'text/plain',
#    'value': u'Looking for FEMALE STRIPPERS ASAP (New York)'},
#   'updated': u'2017-09-16T21:25:27-04:00',
#   'updated_parsed': time.struct_time(tm_year=2017, tm_mon=9, tm_mday=17, tm_hour=1, tm_min=25, tm_sec=27, tm_wday=6, tm_yday=260, tm_isdst=0)},
#  {'dc_source': u'http://newyork.craigslist.org/mnh/stp/6309039467.html',
#   'dc_type': u'text',
#   'id': u'http://newyork.craigslist.org/mnh/stp/6309039467.html',
#   'language': u'en-us',
#   'link': u'http://newyork.craigslist.org/mnh/stp/6309039467.html',
#   'links': [{'href': u'http://newyork.craigslist.org/mnh/stp/6309039467.html',
#     'rel': u'alternate',
#     'type': u'text/html'}],
#   'published': u'2017-09-16T21
',
#   'title_detail': {'base': u'https://newyork.craigslist.org/search/stp?format=rss',
#    'language': None,
#    'type': u'text/plain',
#    'value': u'CAN I COME BE THAT DUDE FOR YOU IF YOU CAN BE THAT GIRL FOR ME? - m4w (Downtown)'},
#   'updated': u'2017-09-16T21:10:08-04:00',
#   'updated_parsed': time.struct_time(tm_year=2017, tm_mon=9, tm_mday=17, tm_hour=1, tm_min=10, tm_sec=8, tm_wday=6, tm_yday=260, tm_isdst=0)},
#  {'dc_source': u'http://newyork.craigslist.org/brk/stp/6306435973.html',
#   'dc_type': u'text',
#   'id': u'http://newyork.craigslist.org/brk/stp/6306435973.html',
#   'language': u'en-us',
#   'link': u'http://newyork.craigslist.org/brk/stp/6306435973.html',
#   'links': [{'href': u'http://newyork.craigslist.org/brk/stp/6306435973.html',
#     'rel': u'alternate',
#     'type': u'text/html'}],
#   'published': u'2017-09-16T21:05:49-04:00',
#   'published_parsed': time.struct_time(tm_year=2017, tm_mon=9, tm_mday=17, tm_hour=1, tm_min=5, tm_sec=49, tm_wday=6, tm_yday=260, tm_isdst=0),
#   'rights': u'copyright 2017 craiglist',
#   'rights_detail': {'base': u'https://newyork.craigslist.org/search/stp?format=rss',
#    'language': None,
#    'type': u'text/plain',
#    'value': u'copyright 2017 craiglist'},
#   'summary': u"Hey, I'm 25 and I am a fun outgoing and bubbly person looking to make some new friends . I love parties, bars, lounges, sometimes dining out, and planning random day trips. I enjoy talking on the phone on my downtime and taking long walks. I am a soc ...",
#   'summary_detail': {'base': u'https://newyork.craigslist.org/search/stp?format=rss',
#    'language': None,
#    'type': u'text/html',
#    'value': u"Hey, I'm 25 and I am a fun outgoing and bubbly person looking to make some new friends . I love parties, bars, lounges, sometimes dining out, and planning random day trips. I enjoy talking on the phone on my downtime and taking long walks. I am a soc ..."},
#   'title': u'Friendsss! - w4w (Brooklyn)',
#   'title_detail': {'base': u'https://newyork.craigslist.org/search/stp?format=rss',
#    'language': None,
#    'type': u'text/plain',
#    'value': u'Friendsss! - w4w (Brooklyn)'},
#   'updated': u'2017-09-16T21:05:49-04:00',
#   'updated_parsed': time.struct_time(tm_year=2017, tm_mon=9, tm_mday=17, tm_hour=1, tm_min=5, tm_sec=49, tm_wday=6, tm_yday=260, tm_isdst=0)},
#  {'dc_source': u'http://newyork.craigslist.org/mnh/stp/6300460047.html',
#   'dc_type': u'text',
#   'id': u'http://newyork.craigslist.org/mnh/stp/6300460047.html',
#   'language': u'en-us',
#   'link': u'http://newyork.craigslist.org/mnh/stp/6300460047.html',
#   'links': [{'href': u'http://newyork.craigslist.org/mnh/stp/6300460047.html',
#     'rel': u'alternate',
#     'type': u'text/html'}],
#   'published': u'2017-09-16T21:03:52-04:00',
#   'published_parsed': time.struct_time(tm_year=2017, tm_mon=9, tm_mday=17, tm_hour=1, tm_min=3, tm_sec=52, tm_wday=6, tm_yday=260, tm_isdst=0),
#   'rights': u'copyright 2017 craiglist',
#   'rights_detail': {'base': u'https://newyork.craigslist.org/search/stp?format=rss',
#    'language': None,
#    'type': u'text/plain',
#    'value': u'copyright 2017 craiglist'},
#   'summary': u"Yes, it's entirely possible to be married and yet still feel utterly alone. There can be many reasons for it, but the end result is the same and feeling alone is never fun. If you're in the same boat, and not looking to change your relationship statu ...",
#   'summary_detail': {'base': u'https://newyork.craigslist.org/search/stp?format=rss',
#    'language': None,
#    'type': u'text/html',
#    'value': u"Yes, it's entirely possible to be married and yet still feel utterly alone. There can be many reasons for it, but the end result is the same and feeling alone is never fun. If you're in the same boat, and not looking to change your relationship statu ..."},
#   'title': u'Lonely MWM seeks Lonely MWF - m4w (NYC)',
#   'title_detail': {'base': u'https://newyork.craigslist.org/search/stp?format=rss',
#    'language': None,
#    'type': u'text/plain',
#    'value': u'Lonely MWM seeks Lonely MWF - m4w (NYC)'},
#   'updated': u'2017-09-16T21:03:52-04:00',
#   'updated_parsed': time.struct_time(tm_year=2017, tm_mon=9, tm_mday=17, tm_hour=1, tm_min=3, tm_sec=52, tm_wday=6, tm_yday=260, tm_isdst=0)},
#  {'dc_source': u'http://newyork.craigslist.org/mnh/stp/6289279542.html',
#   'dc_type': u'text',
#   'id': u'http://newyork.craigslist.org/mnh/stp/6289279542.html',
#   'language': u'en-us',
#   'link': u'http://newyork.craigslist.org/mnh/stp/6289279542.html',
#   'links': [{'href': u'http://newyork.craigslist.org/mnh/stp/6289279542.html',
#     'rel': u'alternate',
#     'type': u'text/html'}],
#   'published': u'2017-09-16T21:03:08-04:00',
#   'published_parsed': time.struct_time(tm_year=2017, tm_mon=9, tm_mday=17, tm_hour=1, tm_min=3, tm_sec=8, tm_wday=6, tm_yday=260, tm_isdst=0),
#   'rights': u'copyright 2017 craiglist',
#   'rights_detail': {'base': u'https://newyork.craigslist.org/search/stp?format=rss',
#    'language': None,
#    'type': u'text/plain',
#    'value': u'copyright 2017 craiglist'},
#   'summary': u'I am family oriented, easy going, happy go lucky, huge heart, sweet, kind, funny, intelligent and pleasant. I am seeking a friend to just hang out sometimes. Go for a walk, just talk, get coffee or lunch.',
#   'summary_detail': {'base': u'https://newyork.craigslist.org/search/stp?format=rss',
#    'language': None,
#    'type': u'text/html',
#    'value': u'I am family oriented, easy going, happy go lucky, huge heart, sweet, kind, funny, intelligent and pleasant. I am seeking a friend to just hang out sometimes. Go for a walk, just talk, get coffee or lunch.'},
#   'title': u'Platonic Friendship - m4w (Chinatown / Lit Italy)',
#   'title_detail': {'base': u'https://newyork.craigslist.org/search/stp?format=rss',
#    'language': None,
#    'type': u'text/plain',
#    'value': u'Platonic Friendship - m4w (Chinatown / Lit Italy)'},
#   'updated': u'2017-09-16T21:03:08-04:00',
#   'updated_parsed': time.struct_time(tm_year=2017, tm_mon=9, tm_mday=17, tm_hour=1, tm_min=3, tm_sec=8, tm_wday=6, tm_yday=260, tm_isdst=0)},
#  {'dc_source': u'http://newyork.craigslist.org/mnh/stp/6289277860.html',
#   'dc_type': u'text',
#   'id': u'http://newyork.craigslist.org/mnh/stp/6289277860.html',
#   'language': u'en-us',
#   'link': u'http://newyork.craigslist.org/mnh/stp/6289277860.html',
#   'links': [{'href': u'http://newyork.craigslist.org/mnh/stp/6289277860.html',
#     'rel': u'alternate',
#     'type': u'text/html'}],
#   'published': u'2017-09-16T21:03:07-04:00',
#   'published_parsed': time.struct_time(tm_year=2017, tm_mon=9, tm_mday=17, tm_hour=1, tm_min=3, tm_sec=7, tm_wday=6, tm_yday=260, tm_isdst=0),
#   'rights': u'copyright 2017 craiglist',
#   'rights_detail': {'base': u'https://newyork.craigslist.org/search/stp?format=rss',
#    'language': None,
#    'type': u'text/plain',
#    'value': u'copyright 2017 craiglist'},
#   'summary': u'Looking for someone nice to chat with sometimes and hopefully build a friendship. I am the pleasant, fun, sweet and warm type of person; laid back, easy going, clean and respectful. \nI work in Midtown so I am free some days for lunch or meet up after ...',
#   'summary_detail': {'base': u'https://newyork.craigslist.org/search/stp?format=rss',
#    'language': None,
#    'type': u'text/html',
#    'value': u'Looking for someone nice to chat with sometimes and hopefully build a friendship. I am the pleasant, fun, sweet and warm type of person; laid back, easy going, clean and respectful. \nI work in Midtown so I am free some days for lunch or meet up after ...'},
#   'title': u'Good Person, Good Friend - m4w (Chinatown / Lit Italy)',
#   'title_detail': {'base': u'https://newyork.craigslist.org/search/stp?format=rss',
#    'language': None,
#    'type': u'text/plain',
#    'value': u'Good Person, Good Friend - m4w (Chinatown / Lit Italy)'},
#   'updated': u'2017-09-16T21:03:07-04:00',
#   'updated_parsed': time.struct_time(tm_year=2017, tm_mon=9, tm_mday=17, tm_hour=1, tm_min=3, tm_sec=7, tm_wday=6, tm_yday=260, tm_isdst=0)},
#  {'dc_source': u'http://newyork.craigslist.org/mnh/stp/6289278429.html',
#   'dc_type': u'text',
#   'id': u'http://newyork.craigslist.org/mnh/stp/6289278429.html',
#   'language': u'en-us',
#   'link': u'http://newyork.craigslist.org/mnh/stp/6289278429.html',
#   'links': [{'href': u'http://newyork.craigslist.org/mnh/stp/6289278429.html',
#     'rel': u'alternate',
#     'type': u'text/html'}],
#   'published': u'2017-09-16T21:03:07-04:00',
#   'published_parsed': time.struct_time(tm_year=2017, tm_mon=9, tm_mday=17, tm_hour=1, tm_min=3, tm_sec=7, tm_wday=6, tm_yday=260, tm_isdst=0),
#   'rights': u'copyright 2017 craiglist',
#   'rights_detail': {'base': u'https://newyork.craigslist.org/search/stp?format=rss',
#    'language': None,
#    'type': u'text/plain',
#    'value': u'copyright 2017 craiglist'},
#   'summary': u'I am family oriented, easy going, happy go lucky, huge heart, sweet, kind, funny, intelligent and pleasant. I am seeking a friend to just hang out sometimes. Go for a walk, just talk, get coffee or lunch.',
#   'summary_detail': {'base': u'https://newyork.craigslist.org/search/stp?format=rss',
#    'language': None,
#    'type': u'text/html',
#    'value': u'I am family oriented, easy going, happy go lucky, huge heart, sweet, kind, funny, intelligent and pleasant. I am seeking a friend to just hang out sometimes. Go for a walk, just talk, get coffee or lunch.'},
#   'title': u'Platonic Friendship - m4w (Chinatown / Lit Italy)',
#   'title_detail': {'base': u'https://newyork.craigslist.org/search/stp?format=rss',
#    'language': None,
#    'type': u'text/plain',
#    'value': u'Platonic Friendship - m4w (Chinatown / Lit Italy)'},
#   'updated': u'2017-09-16T21:03:07-04:00',
#   'updated_parsed': time.struct_time(tm_year=2017, tm_mon=9, tm_mday=17, tm_hour=1, tm_min=3, tm_sec=7, tm_wday=6, tm_yday=260, tm_isdst=0)},
#  {'dc_source': u'http://newyork.craigslist.org/brk/stp/6289281991.html',
#   'dc_type': u'text',
#   'id': u'http://newyork.craigslist.org/brk/stp/6289281991.html',
#   'language': u'en-us',
#   'link': u'http://newyork.craigslist.org/brk/stp/6289281991.html',
#   'links': [{'href': u'http://newyork.craigslist.org/brk/stp/6289281991.html',
#     'rel': u'alternate',
#     'type': u'text/html'}],
#   'published': u'2017-09-16T21:03:02-04:00',
#   'published_parsed': time.struct_time(tm_year=2017, tm_mon=9, tm_mday=17, tm_hour=1, tm_min=3, tm_sec=2, tm_wday=6, tm_yday=260, tm_isdst=0),
#   'rights': u'copyright 2017 craiglist',
#   'rights_detail': {'base': u'https://newyork.craigslist.org/search/stp?format=rss',
#    'language': None,
#    'type': u'text/plain',
#    'value': u'copyright 2017 craiglist'},
#   'summary': u"I'm am a little skeptical about this CL thing. But if you can be open to a non physical, platonic friendship then we'll be a good fit. I've always had girl best friends, so I think that is what's missing in my life right now. I don't have many guy fr ...",
#   'summary_detail': {'base': u'https://newyork.craigslist.org/search/stp?format=rss',
#    'language': None,
#    'type': u'text/html',
#    'value': u"I'm am a little skeptical about this CL thing. But if you can be open to a non physical, platonic friendship then we'll be a good fit. I've always had girl best friends, so I think that is what's missing in my life right now. I don't have many guy fr ..."},
#   'title': u'Non Physical, Platonic Friendship - m4w (Brooklyn)',
#   'title_detail': {'base': u'https://newyork.craigslist.org/search/stp?format=rss',
#    'language': None,
#    'type': u'text/plain',
#    'value': u'Non Physical, Platonic Friendship - m4w (Brooklyn)'},
#   'updated': u'2017-09-16T21:03:02-04:00',
#   'updated_parsed': time.struct_time(tm_year=2017, tm_mon=9, tm_mday=17, tm_hour=1, tm_min=3, tm_sec=2, tm_wday=6, tm_yday=260, tm_isdst=0)}]

# %%
len(ny['entries'])
# Out:
# 25
