# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3083, 12, 6, 195, 2, 3137, 46, 59, 156]

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'originated', 'anarchism', 'a', 'term', 'as', 'originated', 'of']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.699833
# Nearest to three: greenhouse, medley, detectors, woodson, personas, fetuses, gigantic, complexion,
# Nearest to are: leaders, airbase, othello, respectful, gibraltar, denoted, contraception, celtic,
# Nearest to often: nicomedia, silicone, transl, fuji, lighting, read, spotted, islets,
# Nearest to many: alligators, resh, theologian, avoided, tonnes, dreadnought, gbit, burgos,
# Nearest to been: dualistic, accrue, interior, sinclair, knox, consisting, acad, castell,
# Nearest to than: josie, endlessly, halves, classicists, designating, bowls, cronos, undergo,
# Nearest to american: mandating, foregoing, ear, haute, wormholes, regensburg, bh, hydride,
# Nearest to use: ancestor, nash, bianchi, eclipses, authorities, hooper, throat, shostakovich,
# Nearest to with: haze, woodside, deposited, soci, historicism, collier, gloss, bonhomme,
# Nearest to eight: social, sedgwick, cometary, nss, britney, indepth, protists, horticulture,
# Nearest to also: rigdon, derivation, divisible, dimorphism, noll, nol, seigenthaler, salk,
# Nearest to of: reinvent, apennines, dani, withdrew, cory, chiefs, vitoria, hellenized,
# Nearest to united: zuse, amplitudes, incised, refused, workday, drilled, plateaus, repetition,
# Nearest to who: malign, cesare, harlow, telstra, intensified, ah, brentano, mclaughlin,
# Nearest to an: alpacas, lutes, navin, concentric, bonnet, por, silvery, abhorrent,
# Nearest to other: stealthy, lexicography, hornsby, helix, covariance, cymbal, ravaging, conjunctive,
# Average loss at step 2000: 4.358773
# Average loss at step 4000: 3.868378
# Average loss at step 6000: 3.789848
# Average loss at step 8000: 3.687568
# Average loss at step 10000: 3.617850
# Nearest to three: four, seven, six, eight, five, two, nine, zero,
# Nearest to are: were, is, worshippers, have, was, miletus, celebrating, embarks,
# Nearest to often: also, silicone, eng, fuji, lore, nrms, zuma, transl,
# Nearest to many: statistics, alligators, other, limes, some, ihr, vary, spilled,
# Nearest to been: become, dualistic, gaming, be, kv, uproar, consisting, beno,
# Nearest to than: endlessly, josie, cronos, classicists, bowls, halves, advocacy, for,
# Nearest to american: haute, foregoing, catchphrase, mandating, necessitating, medallist, retrial, generalisation,
# Nearest to use: hooper, nash, authorities, bench, acuff, quincy, history, cmt,
# Nearest to with: in, through, of, consider, seif, from, shuster, captaincy,
# Nearest to eight: nine, six, seven, four, five, three, zero, two,
# Nearest to also: divisible, which, often, it, he, actually, not, ailments,
# Nearest to of: in, walled, for, delusions, with, frobisher, sequels, at,
# Nearest to united: zuse, drilled, amplitudes, repetition, gamow, plumbing, plateaus, incised,
# Nearest to who: he, which, and, not, they, never, fela, quayle,
# Nearest to an: the, concentric, roam, por, neighbourhoods, hickman, line, this,
# Nearest to other: conjunctive, maxillofacial, many, cour, helix, dag, connection, covariance,
# Average loss at step 12000: 3.604689
# Average loss at step 14000: 3.576517
# Average loss at step 16000: 3.406291
# Average loss at step 18000: 3.458661
# Average loss at step 20000: 3.539942
# Nearest to three: four, six, five, seven, eight, two, zero, one,
# Nearest to are: were, is, have, percy, exe, worshippers, be, batll,
# Nearest to often: also, silicone, sometimes, eng, fuji, frequently, there, nrms,
# Nearest to many: some, other, several, these, limes, those, spilled, most,
# Nearest to been: become, be, was, uproar, never, were, kv, by,
# Nearest to than: or, josie, endlessly, bowls, circularly, classicists, desilu, halves,
# Nearest to american: british, english, foregoing, scottish, holocene, retrial, necessitating, celluloid,
# Nearest to use: hooper, quincy, cmt, nash, atman, history, flynt, acuff,
# Nearest to with: in, bluebird, between, through, for, from, captaincy, at,
# Nearest to eight: seven, nine, six, five, four, three, zero, two,
# Nearest to also: often, which, not, actually, divisible, sometimes, who, it,
# Nearest to of: chiefs, jewish, for, cricketers, visigoths, in, honda, large,
# Nearest to united: zuse, drilled, amplitudes, coast, gamow, satirically, repetition, plateaus,
# Nearest to who: he, which, never, they, also, not, reza, fela,
# Nearest to an: por, alpacas, consisting, margins, roam, discounts, engraved, the,
# Nearest to other: many, various, these, conjunctive, maxillofacial, conventional, some, moldovans,
# Average loss at step 22000: 3.506773
# Average loss at step 24000: 3.492976
# Average loss at step 26000: 3.485011
# Average loss at step 28000: 3.476783
# Average loss at step 30000: 3.501252
# Nearest to three: four, five, seven, eight, two, six, zero, nine,
# Nearest to are: were, have, is, gerard, these, be, happier, qazaqstan,
# Nearest to often: also, sometimes, frequently, usually, there, easily, generally, now,
# Nearest to many: some, several, these, most, other, all, lobbying, various,
# Nearest to been: become, was, be, were, never, vitamins, uproar, marseilles,
# Nearest to than: josie, endlessly, bowls, tua, or, desilu, classicists, circularly,
# Nearest to american: english, scottish, british, celluloid, assemblers, retrial, german, holocene,
# Nearest to use: hooper, atman, quincy, vibrate, nash, fearful, flynt, cmt,
# Nearest to with: between, through, by, seif, in, including, accelerated, bluebird,
# Nearest to eight: nine, seven, six, five, four, three, zero, two,
# Nearest to also: often, sometimes, actually, it, which, now, glycolytic, divisible,
# Nearest to of: in, frobisher, chiefs, from, and, jewish, gelasian, walled,
# Nearest to united: zuse, drilled, coast, amplitudes, satirically, plateaus, repetition, world,
# Nearest to who: he, they, never, which, and, also, mildly, she,
# Nearest to an: consisting, por, ecclesia, alpacas, hickman, navin, roam, bonnet,
# Nearest to other: various, many, these, different, some, such, cour, conventional,
# Average loss at step 32000: 3.506200
# Average loss at step 34000: 3.496364
# Average loss at step 36000: 3.459619
# Average loss at step 38000: 3.301693
# Average loss at step 40000: 3.429487
# Nearest to three: four, five, two, six, seven, eight, nine, zero,
# Nearest to are: were, have, is, packs, modernize, include, these, although,
# Nearest to often: usually, also, sometimes, frequently, widely, generally, now, there,
# Nearest to many: some, several, these, most, various, authorizes, all, lobbying,
# Nearest to been: become, be, was, never, were, vitamins, underhill, aise,
# Nearest to than: or, endlessly, circularly, ciii, and, retained, desilu, josie,
# Nearest to american: british, german, english, scottish, french, australian, russian, mandating,
# Nearest to use: hooper, ejaculate, atman, fearful, quincy, vibrate, bench, mixture,
# Nearest to with: between, through, in, by, including, on, serge, for,
# Nearest to eight: nine, seven, six, four, five, three, zero, one,
# Nearest to also: often, which, sometimes, now, actually, still, there, never,
# Nearest to of: in, everest, counterattacks, politican, danubian, kung, delusions, for,
# Nearest to united: zuse, drilled, amplitudes, world, reflexive, repetition, plateaus, satirically,
# Nearest to who: he, which, never, they, she, often, fela, there,
# Nearest to an: consisting, alpacas, hickman, ecclesia, olga, kota, por, abhorrent,
# Nearest to other: various, different, propagate, organic, nomad, some, conjunctive, many,
# Average loss at step 42000: 3.436287
# Average loss at step 44000: 3.454128
# Average loss at step 46000: 3.453802
# Average loss at step 48000: 3.354911
# Average loss at step 50000: 3.383639
# Nearest to three: four, six, seven, two, five, eight, nine, zero,
# Nearest to are: were, is, have, packs, be, gerard, gelatin, although,
# Nearest to often: usually, sometimes, generally, frequently, also, now, widely, commonly,
# Nearest to many: some, several, these, various, most, those, both, other,
# Nearest to been: become, be, was, were, vitamins, underhill, had, already,
# Nearest to than: or, endlessly, ciii, and, halves, tua, slightly, but,
# Nearest to american: scottish, english, french, british, australian, european, russian, proud,
# Nearest to use: hooper, ejaculate, fearful, quincy, atman, evacuation, form, bench,
# Nearest to with: between, by, nsc, shuster, through, cannibalism, berio, seif,
# Nearest to eight: six, seven, nine, four, five, three, zero, one,
# Nearest to also: often, which, now, actually, sometimes, divisible, still, then,
# Nearest to of: in, frobisher, including, and, across, delusions, acoustics, from,
# Nearest to united: zuse, drilled, amplitudes, plateaus, repetition, kuwaiti, gamow, dinosaur,
# Nearest to who: he, which, there, never, fela, she, mildly, they,
# Nearest to an: consisting, alpacas, gamelan, mooring, por, navin, abhorrent, amity,
# Nearest to other: various, different, organic, many, bukovina, conjunctive, nomad, those,
# Average loss at step 52000: 3.436849
# Average loss at step 54000: 3.426178
# Average loss at step 56000: 3.437093
# Average loss at step 58000: 3.394722
# Average loss at step 60000: 3.392610
# Nearest to three: five, four, six, eight, two, seven, nine, one,
# Nearest to are: were, is, have, these, include, other, modernize, those,
# Nearest to often: usually, sometimes, commonly, frequently, now, generally, also, widely,
# Nearest to many: some, several, various, these, most, all, other, both,
# Nearest to been: become, be, was, had, were, underhill, skeleton, vitamins,
# Nearest to than: but, much, and, or, ciii, slightly, calvinism, tua,
# Nearest to american: british, european, scottish, french, russian, english, engl, australian,
# Nearest to use: hooper, ejaculate, fearful, form, atman, exist, teamsters, vibrate,
# Nearest to with: between, including, by, seif, when, in, berio, footballers,
# Nearest to eight: nine, six, seven, four, five, three, zero, one,
# Nearest to also: now, often, still, sometimes, never, typically, actually, divisible,
# Nearest to of: in, including, for, lactate, same, although, acoustics, tubular,
# Nearest to united: zuse, drilled, amplitudes, repetition, world, kuwaiti, plateaus, bliss,
# Nearest to who: never, which, he, now, that, fela, she, still,
# Nearest to an: alpacas, consisting, navin, stumbled, concentric, mooring, defective, the,
# Nearest to other: various, many, different, are, organic, those, others, multiple,
# Average loss at step 62000: 3.242444
# Average loss at step 64000: 3.256371
# Average loss at step 66000: 3.403609
# Average loss at step 68000: 3.393702
# Average loss at step 70000: 3.358449
# Nearest to three: four, six, five, two, seven, eight, nine, zero,
# Nearest to are: were, have, is, although, be, include, these, including,
# Nearest to often: usually, sometimes, commonly, generally, frequently, now, widely, also,
# Nearest to many: some, several, various, all, these, most, both, such,
# Nearest to been: become, be, was, had, were, come, underhill, vitamins,
# Nearest to than: or, but, ciii, staunch, endlessly, enraged, and, calvinism,
# Nearest to american: british, scottish, european, french, english, african, australian, engl,
# Nearest to use: hooper, understanding, form, release, flooded, sense, think, ejaculate,
# Nearest to with: between, seif, ocogs, exarchate, including, by, shuster, imperfect,
# Nearest to eight: nine, six, seven, four, five, zero, three, two,
# Nearest to also: now, still, often, which, sometimes, actually, never, typically,
# Nearest to of: including, include, in, anecdotal, gilligan, like, original, for,
# Nearest to united: zuse, drilled, repetition, remaining, amplitudes, reflexive, dinosaur, meo,
# Nearest to who: never, he, she, which, often, fela, generally, now,
# Nearest to an: consisting, alpacas, the, navin, abhorrent, mooring, approve, dever,
# Nearest to other: various, different, many, gauntlets, including, others, organic, propagate,
# Average loss at step 72000: 3.371285
# Average loss at step 74000: 3.347128
# Average loss at step 76000: 3.315854
# Average loss at step 78000: 3.349192
# Average loss at step 80000: 3.379862
# Nearest to three: five, seven, six, two, four, eight, nine, zero,
# Nearest to are: were, is, have, although, include, these, including, gerard,
# Nearest to often: sometimes, usually, commonly, generally, frequently, now, still, typically,
# Nearest to many: some, several, various, these, both, all, most, numerous,
# Nearest to been: become, be, was, were, had, vitamins, already, skeleton,
# Nearest to than: but, or, and, much, calvinism, endlessly, ciii, tua,
# Nearest to american: british, french, scottish, european, english, russian, german, australian,
# Nearest to use: hooper, because, form, understanding, ejaculate, flooded, content, teamsters,
# Nearest to with: between, lotta, ocogs, by, seif, through, in, when,
# Nearest to eight: nine, seven, five, six, four, three, zero, two,
# Nearest to also: now, still, often, sometimes, which, never, actually, kimchi,
# Nearest to of: including, lingered, counterattacks, original, gilligan, presiding, in, everest,
# Nearest to united: zuse, drilled, reflexive, repetition, european, remaining, changing, incised,
# Nearest to who: he, never, she, often, which, they, now, alaskans,
# Nearest to an: alpacas, consisting, mooring, discounts, hickman, navin, arcas, concentric,
# Nearest to other: various, bukovina, including, others, different, many, conventional, upsilon,
# Average loss at step 82000: 3.406906
# Average loss at step 84000: 3.409798
# Average loss at step 86000: 3.386189
# Average loss at step 88000: 3.353567
# Average loss at step 90000: 3.365737
# Nearest to three: five, four, two, seven, eight, six, nine, zero,
# Nearest to are: were, is, have, include, these, although, mithra, manipulates,
# Nearest to often: sometimes, usually, generally, commonly, frequently, now, typically, still,
# Nearest to many: some, several, various, these, all, numerous, most, certain,
# Nearest to been: become, be, already, was, vitamins, begun, taunted, being,
# Nearest to than: enraged, calvinism, or, much, ciii, endlessly, tua, somewhat,
# Nearest to american: british, scottish, french, european, dutch, russian, african, indian,
# Nearest to use: hooper, content, need, because, understanding, ejaculate, teamsters, support,
# Nearest to with: between, by, in, seif, when, through, entailed, karmal,
# Nearest to eight: seven, five, nine, six, four, three, zero, two,
# Nearest to also: now, still, often, which, sometimes, actually, never, typically,
# Nearest to of: for, including, in, during, bethune, facilitator, and, lingered,
# Nearest to united: zuse, drilled, reflexive, waw, dinosaur, remaining, coast, repetition,
# Nearest to who: he, often, which, never, fela, she, also, already,
# Nearest to an: alpacas, consisting, sola, gamelan, stylistic, navin, discounts, wentworth,
# Nearest to other: various, symplectic, others, nomad, pronouncement, different, technicality, including,
# Average loss at step 92000: 3.396752
# Average loss at step 94000: 3.252004
# Average loss at step 96000: 3.359633
# Average loss at step 98000: 3.244315
# Average loss at step 100000: 3.355223
# Nearest to three: five, six, four, two, seven, eight, nine, zero,
# Nearest to are: were, these, have, is, including, while, those, visa,
# Nearest to often: usually, sometimes, commonly, generally, frequently, typically, widely, now,
# Nearest to many: some, several, these, various, all, numerous, few, certain,
# Nearest to been: become, be, already, was, underhill, remained, informant, recently,
# Nearest to than: or, and, much, but, even, ciii, slightly, calvinism,
# Nearest to american: british, scottish, australian, mandating, french, italian, canadian, japanese,
# Nearest to use: hooper, content, because, need, teamsters, understanding, sense, nottingham,
# Nearest to with: between, seif, including, in, shuster, mitra, when, instantaneously,
# Nearest to eight: seven, nine, six, four, five, three, zero, two,
# Nearest to also: now, still, actually, often, sometimes, usually, never, typically,
# Nearest to of: including, original, in, danubian, presiding, during, puzo, from,
# Nearest to united: zuse, drilled, reflexive, waw, constitution, coast, bliss, meo,
# Nearest to who: never, he, which, she, that, palatable, already, often,
# Nearest to an: alpacas, navin, consisting, margins, abhorrent, luthier, another, mooring,
# Nearest to other: various, others, different, pronouncement, philosophers, organic, symplectic, including,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
